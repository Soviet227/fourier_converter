# %% [markdown]
# # Rename

# %%
import os

folder = r'D:\datasetpicture\picture\testdata\fake\\'
count = 1
# count increase by 1 in each iteration
# iterate all files from a directory
for file_name in os.listdir(folder):
    # Construct old file name
    source = folder + file_name

    # Adding the count to the new file name and extension
    #destination = folder + str(count) + ".jpg"
    destination = folder + "do_" + str(count) + ".jpg"

    # Renaming the file
    os.rename(source, destination)
    count += 1
print('All Files Renamed')

print('New Names are')
# verify the result
res = os.listdir(folder)
print(res)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# C:\Users\WINDOW~1\AppData\Local\Temp/ipykernel_24104/3734731078.py in <module>
#      14
#      15     # Renaming the file
# ---> 16     os.rename(source, destination)
#      17     count += 1
#      18 print('All Files Renamed')
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'D:\\datasetpicture\\picture\\testdata\\fake\\\\8.jpg' -> 'D:\\datasetpicture\\picture\\testdata\\fake\\\\do_1.jpg'

# %% [markdown]
# # Compare

# %%
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg 
import matplotlib as mpl
import sympy as smp
import cv2

def compare():
    fig = plt.figure()

    ax2 = fig.add_subplot(1, 2, 1)
    ax2.set_title("Input Image")
    ax2.set_xticks([])
    ax2.set_yticks([])
    input_img = mpimg.imread(os.path.join(c)) 
    ax2.imshow(input_img)

    ax2 = fig.add_subplot(1, 2, 2)
    ax2.set_title("Fourier Image")
    ax2.set_xticks([])
    ax2.set_yticks([])
    fourier_img = cv2.imread(os.path.join('D:/datasetpicture/picture/fake_fourier640/', '1.jpg')) 
    ax2.imshow(fourier_img)

    # Save the full figure...
    fig.savefig('D:/datasetpicture/picture/fake_compare/1.jpg')

    return

# %%
#c = ('C:/testcam/github/fourier_converter/dataset/3.jpg')
c = ('D:/datasetpicture/picture/fake/1.jpg')
compare()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg 
import matplotlib as mpl
import sympy as smp
import numpy as np
import cv2
import os,glob

from os import listdir,makedirs
from os.path import isfile,join
from PIL import Image

path1 = 'D:/datasetpicture/picture/faketest' # Source Folder1
path2 = 'D:/datasetpicture/picture/fakefo' # Source Folder2
dstpath1 = 'D:/datasetpicture/picture/fake_compare' # Destination Folder
try:
    makedirs(dstpath1)
except:
    print ("Directory already exist, images will be written in same folder")
# Folder won't used

files = list(filter(lambda f: isfile(join(path1,f)), listdir(path1)))
fourier = list(filter(lambda ff: isfile(join(path2,ff)), listdir(path2)))

for image in files:
    try:
        fig = plt.figure()
        ax2 = fig.add_subplot(1, 2, 1)
        ax2.set_title("Input Image")
        ax2.set_xticks([])
        ax2.set_yticks([])
        input_img = mpimg.imread(os.path.join(path1,image)) 
        ax2.imshow(input_img)

        dstPath = join(dstpath1,image)
        fig.savefig(dstPath)

    except:
        print ("{} is not saved amon555 :(".format(image))
    
    for img in fourier:
        try:
            ax2 = fig.add_subplot(1, 2, 2)
            ax2.set_title("Fourier Image")
            ax2.set_xticks([])
            ax2.set_yticks([])
            fourier_img = cv2.imread(os.path.join(path2,img)) 
            ax2.imshow(fourier_img)

            dstPath2 = join(dstpath1,img)
            fig.savefig(dstPath2)

        except:
            print ("{} is not converted amon555".format(image))
# Out:
# Directory already exist, images will be written in same folder

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg 
import matplotlib as mpl
import sympy as smp
import numpy as np
import cv2
import os,glob

from os import listdir,makedirs
from os.path import isfile,join
from PIL import Image

path1 = 'D:/datasetpicture/picture/faketest' # Source Folder1
path2 = 'D:/datasetpicture/picture/fakefo' # Source Folder2
dstpath = 'D:/datasetpicture/picture/fake_compare' # Destination Folder
try:
    makedirs(dstpath)
except:
    print ("Directory already exist, images will be written in same folder")
# Folder won't used

files = list(filter(lambda f: isfile(join(path1,f)), listdir(path1)))
fourier = list(filter(lambda f: isfile(join(path2,f)), listdir(path2)))

for image,img in zip((files),(fourier)):
    try:
        fig = plt.figure()
        ax2 = fig.add_subplot(1, 2, 1)
        ax2.set_title("Input Image")
        ax2.set_xticks([])
        ax2.set_yticks([])
        input_img = mpimg.imread(os.path.join(path1,image)) 
        ax2.imshow(input_img)

        ax2 = fig.add_subplot(1, 2, 2)
        ax2.set_title("Fourier Image")
        ax2.set_xticks([])
        ax2.set_yticks([])
        fourier_img = cv2.imread(os.path.join(path2,img)) 
        ax2.imshow(fourier_img)

        dstPath = join(dstpath,image,img)
        fig.savefig(dstPath)

    except:
        print ("{} is not converted amon555".format(image))
# Out:
# Directory already exist, images will be written in same folder
# 1.jpg is not converted amon555
# 2.jpg is not converted amon555
# 3.jpg is not converted amon555
# 4.jpg is not converted amon555
# 5.jpg is not converted amon555

# %% [markdown]
# # COMPARE GRAYSCALE AND FOURIER

# %%
from PIL import Image

source_folder1 = 'D:/datasetpicture/picture/test_resize/'
source_folder2 = 'D:/datasetpicture/picture/real_fourier640/'
target_folder = 'D:/datasetpicture/picture/real_compare/'

n = 500

for img_no in range(1,n+1):
    img1 = (source_folder1+str(img_no)+".jpg")
    img2 = (source_folder2+str(img_no)+".jpg")
    
    images = [Image.open(x) for x in [img1, img2]]
    widths, heights = zip(*(i.size for i in images))

    total_width = sum(widths)
    max_height = max(heights)

    new_im = Image.new('RGB', (total_width, max_height))


    x_offset = 0
    for im in images:
      new_im.paste(im, (x_offset,0))
      x_offset += im.size[0]

    new_im.save(target_folder+str(img_no)+".jpg")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\WINDOW~1\AppData\Local\Temp/ipykernel_13372/2661265583.py in <module>
#      11     img2 = (source_folder2+str(img_no)+".jpg")
#      12
# ---> 13     images = [Image.open(x) for x in [img1, img2]]
#      14     widths, heights = zip(*(i.size for i in images))
#      15
#
# C:\Users\WINDOW~1\AppData\Local\Temp/ipykernel_13372/2661265583.py in <listcomp>(.0)
#      11     img2 = (source_folder2+str(img_no)+".jpg")
#      12
# ---> 13     images = [Image.open(x) for x in [img1, img2]]
#      14     widths, heights = zip(*(i.size for i in images))
#      15
#
# c:\Users\Windows 10\AppData\Local\Programs\Python\Python310\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2973
#    2974     if filename:
# -> 2975         fp = builtins.open(filename, "rb")
#    2976         exclusive_fp = True
#    2977
#
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg 
import matplotlib as mpl
import sympy as smp
import numpy as np
import cv2
import os,glob

from os import listdir,makedirs
from os.path import isfile,join
from PIL import Image

path1 = 'D:/datasetpicture/picture/faketest' # Source Folder1
path2 = 'D:/datasetpicture/picture/fakefo' # Source Folder2
dstpath1 = 'D:/datasetpicture/picture/fake_compare' # Destination Folder
try:
    makedirs(dstpath1)
except:
    print ("Directory already exist, images will be written in same folder")
# Folder won't used

files = list(filter(lambda f: isfile(join(path1,f)), listdir(path1)))
fourier = list(filter(lambda ff: isfile(join(path2,ff)), listdir(path2)))

for image in files:
    try:
        fig = plt.figure()
        ax2 = fig.add_subplot(1, 2, 1)
        ax2.set_title("Input Image")
        ax2.set_xticks([])
        ax2.set_yticks([])
        input_img = mpimg.imread(os.path.join(path1,image)) 
        ax2.imshow(input_img)

        dstPath = join(dstpath1,image)
        fig.savefig(dstPath)

    except:
        print ("{} is not saved amon555 :(".format(image))
    
    for img in fourier:
        try:
            ax2 = fig.add_subplot(1, 2, 2)
            ax2.set_title("Fourier Image")
            ax2.set_xticks([])
            ax2.set_yticks([])
            fourier_img = cv2.imread(os.path.join(path2,img)) 
            ax2.imshow(fourier_img)

            dstPath2 = join(dstpath1,img)
            fig.savefig(dstPath2)

        except:
            print ("{} is not converted amon555".format(image))
# Out:
# Directory already exist, images will be written in same folder

# %%
folder = 'D:/datasetpicture/picture/fakete' # Source Folder1
folder2 = 'D:/datasetpicture/picture/fakefo' # Source Folder2
dstpath = 'D:/datasetpicture/picture/fake_compare' # Destination Folder

images = []
i=0
for filename, filename2 in zip(os.listdir(folder), os.listdir(folder2)):
        img1 = cv2.imread(os.path.join(folder,filename))
        img2 = cv2.imread(os.path.join(folder2,filename2))
        img2 = np.fliplr(img2)
        vis = np.concatenate((img1, img2), axis=1)
        cv2.imwrite(dstPath,vis)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\WINDOW~1\AppData\Local\Temp/ipykernel_1528/3948332893.py in <module>
#      10         img2 = np.fliplr(img2)
#      11         ax2.imshow(img1)
# ---> 12         vis = np.concatenate((img1, img2), axis=1)
#      13         cv2.imwrite(dstPath,vis)
#      14         ax2.imshow(img1)
#
# c:\Users\Windows 10\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\overrides.py in concatenate(*args, **kwargs)
#
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 640 and the array at index 1 has size 128

# %%
from PIL import Image
# Open images and store them in a list

folder = 'D:/datasetpicture/picture/fakete' # Source Folder1
folder2 = 'D:/datasetpicture/picture/fakefo' # Source Folder2
dstpath = 'D:/datasetpicture/picture/fake_compare' # Destination Folder

images = []
i=0
for filename, filename2 in zip(os.listdir(folder), os.listdir(folder2)):


images = [Image.open(x) for x in ['D:/datasetpicture/picture/fakete', 'D:/datasetpicture/picture/fakefo']]

total_width = 0
max_height = 0
# find the width and height of the final image
for img in images:
    total_width += img.size[0]
    max_height = max(max_height, img.size[1])
# create a new image with the appropriate height and width
new_img = Image.new('RGB', (total_width, max_height))
# Write the contents of the new image
current_width = 0
for img in images:
    new_img.paste(img, (current_width,0))
    current_width += img.size[0]
# Save the image
new_img.save('D:/datasetpicture/picture/fake_compare')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# C:\Users\WINDOW~1\AppData\Local\Temp/ipykernel_1528/317972003.py in <module>
#       1 from PIL import Image
#       2 # Open images and store them in a list
# ----> 3 images = [Image.open(x) for x in ['D:/datasetpicture/picture/fakete', 'D:/datasetpicture/picture/fakefo']]
#       4 total_width = 0
#       5 max_height = 0
#
# C:\Users\WINDOW~1\AppData\Local\Temp/ipykernel_1528/317972003.py in <listcomp>(.0)
#       1 from PIL import Image
#       2 # Open images and store them in a list
# ----> 3 images = [Image.open(x) for x in ['D:/datasetpicture/picture/fakete', 'D:/datasetpicture/picture/fakefo']]
#       4 total_width = 0
#       5 max_height = 0
#
# c:\Users\Windows 10\AppData\Local\Programs\Python\Python310\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2973
#    2974     if filename:
# ...

# %%
import pandas as pd
import cv2
import numpy as np
import glob
import os

source_folder1 = 'D:/datasetpicture/picture/test_resize/'
source_folder2 = 'D:/datasetpicture/picture/real_fourier640/'
target_folder = 'D:/datasetpicture/picture/real_compare/'


filenames1 = glob.glob('D:/datasetpicture/picture/test_resize/')
filenames1.sort()
filenames2 = glob.glob('D:/datasetpicture/picture/real_fourier640/')
filenames2.sort()
filenames3 = glob.glob('D:/datasetpicture/picture/real_compare/')
filenames3.sort()


for f1,f2,f3 in zip(filenames1,filenames2,filenames3):
            img1 = cv2.imread(f1)
            img2 = cv2.imread(f2)
            img3 = cv2.imread(f3)
            img_m1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
            img_m2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
            img_m3 = cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)
            img_rgb = cv2.merge((img_m1, img_m2, img_m3))
            cv2.imwrite("data_folder/merge/img_name.png", img_rgb)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# C:\Users\WINDOW~1\AppData\Local\Temp/ipykernel_13372/823627710.py in <module>
#      22             img2 = cv2.imread(f2)
#      23             img3 = cv2.imread(f3)
# ---> 24             img_m1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
#      25             img_m2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
#      26             img_m3 = cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)
#
# error: OpenCV(4.6.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
